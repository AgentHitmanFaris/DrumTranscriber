# %% [markdown]
# # Local Drum Transcriber
#
# Run this notebook to use the Drum Transcriber directly here (Embedded/Inline).
#
# **Note:** Ensure you have installed the dependencies:
# ```bash
# pip install gradio yt-dlp librosa tensorflow pandas numpy plotly scikit-learn
# ```

# %%
import os
import sys

# Ensure we can import from the current directory
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())

from gradio_app import demo, load_model

# Pre-load model (optional, good for checking errors)
model = load_model()
if model is None:
    print("WARNING: Model not found. Please ensure 'model/drum_transcriber.h5' exists.")

# Launch inline
print("Launching app inline...")
demo.launch(inline=True, share=False, height=800)
